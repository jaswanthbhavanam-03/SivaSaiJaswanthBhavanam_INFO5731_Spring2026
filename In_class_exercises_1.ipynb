# %% [markdown]
# <a href="https://colab.research.google.com/github/jaswanthbhavanam-03/SivaSaiJaswanthBhavanam_INFO5731_Spring2026/blob/main/In_class_exercises_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In-Class Assignment — Week 2 (Lesson 2)**
#
# Time: 20–30 minutes
# Points: 10
#
# **Instructions**
#
# This is an individual in-class assignment.
#
# Complete it during class time.
#
# You may use Week 2 lecture notes / demo notebooks.
#
# Write your code under each question and print the output.
#
# Submit the GitHub link.

# %% [markdown]
# ## Question 1 ( 2 point)
# Write a Python program that  prompts the user to input the length and width of a rectangle, and then calculates and displays the area of the rectangle.

# %%
# Prompt the user to enter the length of the rectangle
length = float(input("Enter the length: "))

# Prompt the user to enter the width of the rectangle
width = float(input("Enter the width: "))

# Calculate the area of the rectangle
area = length * width

# Display the result
print("Area of the rectangle:", area)
# Out:
# Enter the length: 15
# Enter the width: 21
# Area of the rectangle: 315.0

# %% [markdown]
# ## Question 2 ( 2 point)
# Create a Python program that interactively takes two numerical inputs from the user and swaps their values without utilizing an extra variable.

# %%
# Take two numbers as input from the user
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

# Swap the values without using an extra variable
a, b = b, a

# Display the swapped values
print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 3
# Enter second number: 5
# After swapping:
# a = 5.0
# b = 3.0

# %% [markdown]
# ## Question 3 ( 2 point)
# Write a Python script to determine and print the length of a user-input string.

# %%
# Take a string input from the user
text = input("Enter a string: ")

# Print the length of the string
print("Length of the string:", len(text))
# Out:
# Enter a string: Hello this is Student
# Length of the string: 21

# %% [markdown]
# ## Question 4 ( 2 point)
# Design a Python function to check if a number is prime.

# %%
# Define a function to check whether a number is prime
def is_prime(n):
    # Numbers less than or equal to 1 are not prime
    if n <= 1:
        return False

    # Check divisibility from 2 to square root of n
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False

    # If no divisors found, the number is prime
    return True

# Take input from the user
num = int(input("Enter a number: "))

# Check and display the result
if is_prime(num):
    print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# Enter a number: 29
# 29 is a prime number

# %% [markdown]
# ## Question 5 ( 2 point)
# Write a Python program to concatenate following dictionaries to create a new one.
#
# Sample Dictionary : dic1={1:10, 2:20}, dic2={3:30, 4:40}, dic3={5:50,6:60},
#
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
# Define three sample dictionaries
dic1 = {1:10, 2:20}
dic2 = {3:30, 4:40}
dic3 = {5:50, 6:60}

# Create an empty dictionary to store the result
result = {}

# Add all dictionaries into the result dictionary
result.update(dic1)
result.update(dic2)
result.update(dic3)

# Print the final merged dictionary
print(result)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
